# %%
import numpy as np

# %%
arreglo = np.random.randint(1,10,12)
arreglo
# Out:
# array([4, 6, 7, 8, 1, 7, 9, 5, 7, 7, 5, 3])

# %%
np.shape(arreglo)
# Out:
# (9,)

# %%
matriz = arreglo.reshape(4,3)
matriz
# Out:
# array([[4, 6, 7],
#        [8, 1, 7],
#        [9, 5, 7],
#        [7, 5, 3]])

# %%
np.shape(matriz)
# Out:
# (4, 3)
